# %%
from dotenv import load_dotenv
from langchain_openai.chat_models import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
load_dotenv()

model = ChatGoogleGenerativeAI(model = 'gemini-2.5-flash',temperature=0.0)
# model = ChatGoogleGenerativeAI(model='gpt-5-nano',temperature = 0.0 , max_tokens = 1000)

# %%
response = model.invoke("Tell me Today date and time")  #Query example - Tell
print(response)
print(response.content)
# Out:
# content="Today's date and time is:\n\n**June 10, 2024 at 10:48 AM UTC** (Coordinated Universal Time)" additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019b5a51-8cd6-7cd1-a86c-bd1c91f83d80-0' usage_metadata={'input_tokens': 7, 'output_tokens': 71, 'total_tokens': 78, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 35}}
# Today's date and time is:
#
# **June 10, 2024 at 10:48 AM UTC** (Coordinated Universal Time)

# %%
response = model.invoke("What is Python")  #Query example - Tell
print(response)
print(response.content)
# Out:
# content='**Python is a high-level, interpreted, general-purpose programming language.**\n\nCreated by Guido van Rossum and first released in 1991, Python is known for its readability, simplicity, and versatility, making it one of the most popular programming languages today.\n\nHere\'s a breakdown of what that means and why it\'s so widely used:\n\n1.  **High-Level:**\n    *   You don\'t need to worry about low-level memory management or complex machine-level operations. Python abstracts away a lot of the complexity, allowing developers to focus on solving problems rather than managing computer hardware details.\n\n2.  **Interpreted:**\n    *   Unlike compiled languages (like C++ or Java), Python code is executed line by line directly by an interpreter, rather than being compiled into machine code before runtime. This makes the development cycle faster as you don\'t have a separate compilation step.\n\n3.  **General-Purpose:**\n    *   Python isn\'t specialized for one specific domai
# ...
